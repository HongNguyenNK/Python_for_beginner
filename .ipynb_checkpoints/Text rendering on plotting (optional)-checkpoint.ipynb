# %% [markdown]
# # Latex

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.arange(0.0, 2.0 + 0.01, 0.01)
s = np.cos(np.pi * t) + 2.5

plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.plot(t, s)

plt.xlabel(r'\textbf{time} (s)')
plt.ylabel(r'\textit{voltage} (mV)',fontsize=16)
plt.title(r"\TeX\ is Number "
          r"$\displaystyle\sum_{n=1}^\infty\frac{-e^{i\pi}}{2^n}$!",
          fontsize=16, color='gray')
# Make room for the ridiculously large title.
plt.subplots_adjust(top=0.8)

plt.savefig('tex_demo')
## saving as pdf
#plt.savefig("tex_demo.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ## XKCD

# %%
# %pylab inline
plt.xkcd()
plt.plot(sin(linspace(0, 10)))
plt.title('Whoo Hoo!!!, this is how my mood goes !!')
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.xkcd()
# The slices will be ordered and plotted counter-clockwise.
labels = 'NO idea', 'Dark Matter', 'Find the cute theme', 'Actual Working'
sizes = [70, 20, 7, 3]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
explode = (0, 0, 0, 0.1) # only "explode" the 4th slice (i.e. 'XKCD')
plt.title('Writing thesis')
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=30)
# Set aspect ratio to be equal so that pie is drawn as a circle.
plt.axis('equal')
plt.show()
